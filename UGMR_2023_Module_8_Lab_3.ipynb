# %% [markdown]
# <a href="https://colab.research.google.com/github/MedhaviNasare02/Tutorial1/blob/main/UGMR_2023_Module_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-05 12:07:53--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  70.5MB/s    in 1.0s
#
# 2024-04-05 12:07:56 (70.5 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 22732  1705.07585v2  The increasing size and complexity of scientif...  stat
# 37631  1711.06347v1  We address a family of hard benchmark instance...    cs
# 20704  1610.08853v1  Objective: In this paper, we develop a persona...    cs
# 11339  1510.05417v1  This paper concerns a method of selecting a su...  stat
# 24633   1409.6813v2  Existing techniques for 3D action recognition ...    cs
# ...             ...                                                ...   ...
# 7184   1710.11272v1  We provide an overview of several non-linear a...    cs
# 414    1803.07679v1  In this paper, we describe a solution to tackl...  stat
# 7108   1710.05359v3  Recent advances in weakly supervised classific...  stat
# 40821   1405.1304v1  In this paper we present applications of diffe...    cs
# 4654    1205.2606v1  This paper presents a new algorithm for online...    cs
#
#                                                    title  year  \
# 22732  Union of Intersections (UoI) for Interpretable...  2017
# 37631  Conditional Markov Chain Search for the Simple...  2017
# 20704  Personalized Risk Scoring for Critical Care Pr...  2016
# 11339  Piecewise-Linear Approximation for Feature Sub...  2015
# 24633  Histogram of Oriented Principal Components for...  2014
# ...                                                  ...   ...
# 7184   Empirical analysis of non-linear activation fu...  2017
# 414    Product Characterisation towards Personalisati...  2018
# 7108   Information-Theoretic Representation Learning ...  2017
# 40821  Application of Machine Learning Techniques in ...  2014
# 4654   Exploring compact reinforcement-learning repre...  2012
#
#                                                 keywords
# 22732  [increasing, complexity, scientific, dramatica...
# 37631  [benchmark, instances, uncapacitated, fischett...
# 20704  [objective, personalized, algorithm, assessmen...
# 11339  [selecting, sequential, quadratic, optimizatio...
# 24633  [techniques, recognition, sensitive, viewpoint...
# ...                                                  ...
# 7184   [activation, functions, architecture, successf...
# 414    [challenges, continually, catalogue, challenge...
# 7108   [supervised, classification, classifier, unlab...
# 40821  [applications, different, algorithms, aquacult...
# 4654   [algorithm, regression, efficiency, guarantees...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 22732    [increasing, complexity, scientific, dramatica...
# 37631    [benchmark, instances, uncapacitated, fischett...
# 20704    [objective, personalized, algorithm, assessmen...
# 11339    [selecting, sequential, quadratic, optimizatio...
# 24633    [techniques, recognition, sensitive, viewpoint...
#                                ...
# 34288    [addresses, community, discussion, importance,...
# 22220    [interested, measurement, instances, underlyin...
# 10327    [supervised, expressions, automatically, conne...
# 40376    [cognitive, collection, autonomous, strategica...
# 22183    [regression, predictive, extremely, challengin...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8756 words.
# Out of those 4538 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="14c2dc4d-5ecc-44d7-82f0-9d1a5e10c457" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("14c2dc4d-5ecc-44d7-82f0-9d1a5e10c457")) {                    Plotly.newPlot(                        "14c2dc4d-5ecc-44d7-82f0-9d1a5e10c457",                        [{"x":["numerical","demonstrate","realizing","parsimony","investigation","recordings","extensive","potential","interpretable","prediction","phenotypes","intersections","dramatically","respectively","estimation","scientific","operations","discovery","extraction","classification","introduce","complexity","maintaining","increasing","predictive","phenotype","biomedical","interpretation","intersection","statistical","benchmark","applications","framework","algorithm","synthetic","factorization","functional","selection","electrophysiology","solutions","heuristics","employing","configurations","efficient","experiments","components","technique","expertise","metaheuristic","performing","development","conditional","deterministic","instances","algorithmic","optimisation","comparing","procedures","operators","implementing","available","automated","manageable","completed","composition","generation","literature","meaningful","configuration","parameters","importance","heterogeneity","significantly","methodology","consistently","conclusion","intensive","information","prognosis","critically","timeliness","significance","relationship","significant","techniques","inpatient","objective","personalized","accounting","conducted","currently","electronic","clinically","admissions","physiological","associated","processes","admission","assessments","outperforms","heterogeneous","accordingly","minimizing","formulation","computational","optimization","piecewise","approximation","selecting","criterion","sequential","quadratic","descriptors","descriptor","sequences","principal","performance","experimental","evaluated","recognition","improvement","eigenvectors","variations","detection","locations","normalized","keypoints","sensitive","dependent","viewpoint","distribution","histogram","projecting","invariant","establish","divergence","dimension","conceptually","assumption","convexity","distributions","probability","diffusion","convergence","considering","geometric","illustrate","generator","synthesis","unsupervised","approaches","completely","increasingly","behaviors","expressive","attracted","orthogonal","bijective","important","principle","collapsing","generated","guarantee","attention","enclosing","advantages","particular","efficiently","representation","avoidance","nonlinear","possesses","parameterized","characterize","minimizes","algorithms","regardless","questions","generalized","aggregating","functions","predictions","elaborate","previously","identifying","realistic","adversarial","collection","leveraging","population","decomposition","preferences","comparison","crowdsourced","inversely","recovering","establishing","corresponding","disambiguating","proportional"],"y":[92,560,4,1,27,9,160,147,28,234,1,0,17,96,186,32,82,53,129,502,348,235,29,91,53,1,15,61,23,172,228,429,581,871,131,47,38,175,1,154,37,35,26,421,587,92,251,10,13,70,128,78,48,110,44,20,85,41,56,29,314,104,5,7,26,141,139,52,27,238,70,7,265,73,41,17,21,686,5,10,2,22,74,249,347,3,170,17,6,83,48,20,10,1,8,124,87,5,9,257,34,13,51,78,295,316,12,115,43,46,72,31,45,32,111,32,880,400,143,377,137,6,84,332,45,35,8,57,82,24,213,27,11,60,47,23,65,8,77,8,110,167,25,115,67,72,75,32,37,152,408,46,58,26,31,16,13,1,331,51,1,179,31,164,3,84,265,177,332,4,64,7,22,45,15,616,18,61,67,13,231,83,5,91,81,67,94,68,44,47,62,39,114,4,3,23,11,149,5,17],"type":"bar"},{"x":["numerical","demonstrate","realizing","parsimony","investigation","recordings","extensive","poten ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4538,), (4538, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7933333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Cross</span> <span style=''>Domain</span> <span style=''>Sparse</span> <span style=''>Coding</span> <br/><br/><span style=''>Sparse</span> <span style=''>coding</span> <span style=''>has</span> <span style=''>shown</span> <span style=''>its</span> <span style=''>power</span> <span style=''>as</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.33164556962025316);'>effective</span> <span style=''>data</span> <span style='background-color:rgba(0, 255, 0, 0.33066132264529047);'>representation</span> <span style=''>method</span> <span style=''>However</span> <span style=''>up</span> <span style=''>to</span> <span style=''>now</span> <span style=''>all</span> <span style=''>the</span> <span style=''>sparse</span> <span style=''>coding</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approaches</span> <span style=''>are</span> <span style=''>limited</span> <span style=''>within</span> <span style=''>the</span> <span style=''>single</span> <span style=''>domain</span> <span style=''>learning</span> <span style=''>problem</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>extend</span> <span style=''>the</span> <span style=''>sparse</span> <span style=''>coding</span> <span style=''>to</span> <span style=''>cross</span> <span style=''>domain</span> <span style=''>learning</span> <span style=''>problem</span> <span style=''>which</span> <span style=''>tries</span> <span style=''>to</span> <span style=''>learn</span> <span style=''>from</span> <span style=''>a</span> <span style=''>source</span> <span style=''>domain</span> <span style=''>to</span> <span style=''>a</span> <span style=''>target</span> <span style=''>domain</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>significant</span> <span style='background-color:rgba(0, 255, 0, 0.34067952249770433);'>different</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>We</span> <span style=''>impose</span> <span style=''>the</span> <span style=''>Maximum</span> <span style=''>Mean</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Discrepancy</span> <span style=''>(MMD)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>criterion</span> <span style=''>to</span> <span style=''>reduce</span> <span style=''>the</span> <span style=''>cross</span> <span style=''>domain</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style='background-color:rgba(0, 255, 0, 0.303370786516854);'>difference</span> <span style=''>of</span> <span style=''>sparse</span> <span style=''>codes</span> <span style=''>and</span> <span style=''>also</span> <span style='background-color:rgba(0, 255, 0, 0.5384615384615384);'>regularize</span> <span style=''>the</span> <span style=''>sparse</span> <span style=''>codes</span> <span style=''>by</span> <span style=''>the</span> <span style=''>class</span> <span style=''>labels</span> <span style=''>of</span> <span style=''>the</span> <span style=''>samples</span> <span style=''>from</span> <span style=''>both</span> <span style=''>domains</span> <span style=''>to</span> <span style=''>increase</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.552);'>discriminative</span> <span style=''>ability</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3125);'>encouraging</span> <span style='background-color:rgba(0, 255, 0, 0.33928571428571425);'>experiment</span> <span style=''>results</span> <span style=''>of</span> <span style=''>the</span> <span style=''>proposed</span> <span style=''>cross</span> <span style=''>domain</span> <span style=''>sparse</span> <span style=''>coding</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>on</span> <span style=''>two</span> <span style='background-color:rgba(0, 255, 0, 0.4322250639386 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Distributed</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Processes</span> <br/><br/><span style=''>To</span> <span style=''>scale</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style=''>(GPs)</span> <span style=''>to</span> <span style=''>large</span> <span style=''>data</span> <span style=''>sets</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>the</span> <span style=''>robust</span> <span style=''>Bayesian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Committee</span> <span style=''>Machine</span> <span style=''>(rBCM)</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>practical</span> <span style=''>and</span> <span style=''>scalable</span> <span style=''>product</span> <span style=''>of</span> <span style=''>experts</span> <span style=''>model</span> <span style=''>for</span> <span style=''>large</span> <span style=''>scale</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distributed</span> <span style=''>GP</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>Unlike</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style=''>sparse</span> <span style=''>GP</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximations</span> <span style=''>the</span> <span style=''>rBCM</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conceptually</span> <span style=''>simple</span> <span style=''>and</span> <span style=''>does</span> <span style=''>not</span> <span style=''>rely</span> <span style=''>on</span> <span style=''>inducing</span> <span style=''>or</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style=''>The</span> <span style=''>key</span> <span style=''>idea</span> <span style=''>is</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recursively</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribute</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computations</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>independent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computational</span> <span style=''>units</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>subsequently</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>recombine</span> <span style=''>them</span> <span style=''>to</span> <span style=''>form</span> <span style=''>an</span> <span style=''>overall</span> <span style=''>result</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Efficient</span> <span style=''>closed</span> <span style=''>form</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>allows</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>straightforward</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parallelisation</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distributed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computations</span> <span style=''>with</span> <span style=''>a</span> <span style=''>small</span> <span style=''>memory</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>footprint</span> <span style=''>The</span> <span style=''>rBCM</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>independent</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computational</span> <span style=''>graph</span>  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.3097345132743363);'>Mathematical</span> <span style=''>Theory</span> <span style=''>of</span> <span style=''>Learning</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3097345132743363);'>mathematical</span> <span style=''>theory</span> <span style=''>of</span> <span style=''>learning</span> <span style=''>is</span> <span style=''>proposed</span> <span style=''>that</span> <span style=''>has</span> <span style=''>many</span> <span style='background-color:rgba(255, 0, 0, 0.6666666666666665);'>parallels</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3029439696106363);'>information</span> <span style=''>theory</span> <span style=''>We</span> <span style=''>consider</span> <span style=''>Vapniks</span> <span style=''>General</span> <span style=''>Setting</span> <span style=''>of</span> <span style=''>Learning</span> <span style=''>in</span> <span style=''>which</span> <span style=''>the</span> <span style=''>learning</span> <span style=''>process</span> <span style=''>is</span> <span style=''>defined</span> <span style=''>to</span> <span style=''>be</span> <span style=''>the</span> <span style=''>act</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>selecting</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hypothesis</span> <span style=''>in</span> <span style=''>response</span> <span style=''>to</span> <span style=''>a</span> <span style=''>given</span> <span style=''>training</span> <span style=''>set</span> <span style=''>Such</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hypothesis</span> <span style=''>can</span> <span style=''>for</span> <span style=''>example</span> <span style=''>be</span> <span style=''>a</span> <span style=''>decision</span> <span style=''>boundary</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.7142857142857142);'>centroids</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style=''>or</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style=''>frequent</span> <span style=''>item</span> <span style=''>sets</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>association</span> <span style=''>rule</span> <span style=''>mining</span> <span style='background-color:rgba(0, 255, 0, 0.30158730158730157);'>Depending</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hypothesis</span> <span style=''>space</span> <span style=''>and</span> <span style=''>how</span> <span style=''>the</span> <span style=''>final</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hypothesis</span> <span style=''>is</span> <span style=''>selected</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>a</span> <span style=''>learning</span> <span style=''>process</span> <span style=''>can</span> <span style=''>be</span> <span style=''>assigned</span> <span style=''>a</span> <span style=''>numeric</span> <span style=''>score</span> <span style=''>called</span> <span style=''>learning</span> <span style=''>capacity</span> <span style=''>which</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3333333333333333);'>analogous</span> <span style=''>to</span> <span style=''>Shannons</span> <span style=''>channel</span> <span style=''>capacity</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.5384615384615385);'>satisfies</span> <span style=''>similar</span> <spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Max</span> <span style=''>K</span> <span style=''>armed</span> <span style=''>bandit</span> <span style=''>On</span> <span style=''>the</span> <span style=''>ExtremeHunter</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>and</span> <span style=''>beyond</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style=''>is</span> <span style=''>devoted</span> <span style=''>to</span> <span style=''>the</span> <span style=''>study</span> <span style=''>of</span> <span style=''>the</span> <span style=''>max</span> <span style=''>K</span> <span style=''>armed</span> <span style=''>bandit</span> <span style=''>problem</span> <span style=''>which</span> <span style=''>consists</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sequentially</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>allocating</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>resources</span> <span style=''>in</span> <span style=''>order</span> <span style=''>to</span> <span style=''>detect</span> <span style=''>extreme</span> <span style=''>values</span> <span style=''>Our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>contribution</span> <span style=''>is</span> <span style=''>twofold</span> <span style=''>We</span> <span style=''>first</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significantly</span> <span style=''>refine</span> <span style=''>the</span> <span style=''>analysis</span> <span style=''>of</span> <span style=''>the</span> <span style=''>ExtremeHunter</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>carried</span> <span style=''>out</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Carpentier</span> <span style=''>and</span> <span style=''>Valko</span> <span style=''>(2014)</span> <span style=''>and</span> <span style=''>next</span> <span style=''>propose</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>alternative</span> <span style=''>approach</span> <span style=''>showing</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>remarkably</span> <span style=''>Extreme</span> <span style=''>Bandits</span> <span style=''>can</span> <span style=''>be</span> <span style=''>reduced</span> <span style=''>to</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classical</span> <span style=''>version</span> <span style=''>of</span> <span style=''>the</span> <span style=''>bandit</span> <span style=''>problem</span> <span style=''>to</span> <span style=''>a</span> <span style=''>certain</span> <span style=''>extent</span> <span style=''>Beyond</span> <span style=''>the</span> <span style=''>formal</span> <span style=''>analysis</span> <span style=''>these</span> <span style=''>two</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>are</span> <span style=''>compared</span> <span style=''>through</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>numerical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experiments</span> <br/><br/>

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	segmentation (0.06728045325779036)
# 	knowledge (0.12039660056657224)
# 	experimental (0.141643059490085)
# 	processing (0.10729461756373938)
# 	information (0.24291784702549576)
# 	architecture (0.09525495750708216)
# 	detection (0.11756373937677053)
# 	different (0.2584985835694051)
# 	recognition (0.1334985835694051)
# 	convolutional (0.13385269121813032)
#
# Some Statistics words are:
# 	convergence (0.12550607287449392)
# 	variables (0.12955465587044535)
# 	algorithm (0.4008097165991903)
# 	statistical (0.15587044534412955)
# 	theoretical (0.15738866396761134)
# 	distribution (0.18016194331983806)
# 	estimation (0.17408906882591094)
# 	inference (0.19736842105263158)
# 	dimensional (0.1811740890688259)
# 	regression (0.18066801619433198)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="96efa4b4-e3d8-4ac0-875a-f409cff04ab3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("96efa4b4-e3d8-4ac0-875a-f409cff04ab3")) {                    Plotly.newPlot(                        "96efa4b4-e3d8-4ac0-875a-f409cff04ab3",                        [{"x":["numerical","demonstrate","realizing","parsimony","investigation","recordings","extensive","potential","interpretable","prediction","phenotypes","intersections","dramatically","respectively","estimation","scientific","operations","discovery","extraction","classification","introduce","complexity","maintaining","increasing","predictive","phenotype","biomedical","interpretation","intersection","statistical","benchmark","applications","framework","algorithm","synthetic","factorization","functional","selection","electrophysiology","solutions","heuristics","employing","configurations","efficient","experiments","components","technique","expertise","metaheuristic","performing","development","conditional","deterministic","instances","algorithmic","optimisation","comparing","procedures","operators","implementing","available","automated","manageable","completed","composition","generation","literature","meaningful","configuration","parameters","importance","heterogeneity","significantly","methodology","consistently","conclusion","intensive","information","prognosis","critically","timeliness","significance","relationship","significant","techniques","inpatient","objective","personalized","accounting","conducted","currently","electronic","clinically","admissions","physiological","associated","processes","admission","assessments","outperforms","heterogeneous","accordingly","minimizing","formulation","computational","optimization","piecewise","approximation","selecting","criterion","sequential","quadratic","descriptors","descriptor","sequences","principal","performance","experimental","evaluated","recognition","improvement","eigenvectors","variations","detection","locations","normalized","keypoints","sensitive","dependent","viewpoint","distribution","histogram","projecting","invariant","establish","divergence","dimension","conceptually","assumption","convexity","distributions","probability","diffusion","convergence","considering","geometric","illustrate","generator","synthesis","unsupervised","approaches","completely","increasingly","behaviors","expressive","attracted","orthogonal","bijective","important","principle","collapsing","generated","guarantee","attention","enclosing","advantages","particular","efficiently","representation","avoidance","nonlinear","possesses","parameterized","characterize","minimizes","algorithms","regardless","questions","generalized","aggregating","functions","predictions","elaborate","previously","identifying","realistic","adversarial","collection","leveraging","population","decomposition","preferences","comparison","crowdsourced","inversely","recovering","establishing","corresponding","disambiguating","proportional","partially","fundamental","populations","relational","graphical","explicitly","designing","searching","candidate","relaxation","arbitrary","iteratively","inference","enumerate","consistency","additional","tractable","constraints","intrinsic","attribute","typically","polynomial","application","capturing","reflectance","effective","effectiveness","considers","illumination","quantized","appearance","segmentation","discriminating","variation","extrinsic","unbalanced","extension","biological","organization","similarity","challenging","propagation","distinctive","addressing","separation","multitask","evaluation","represented","relatedness","dissimilarity","empirically","annotated","hierarchical","recurrent","multiplications","performed","classical", ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	intersections
# 	trilinear
# 	eigendecomposition
# 	stragglers
# 	percolation
# 	epidemics
# 	datapoints
# 	heteroscedasticity
# 	statisticians
# 	unraveling
# 	unregularized
# 	coincides
# 	mitigates
# 	nutrition
# 	progresses
# 	heteroscedastic
# 	affinities
# 	thermostats
# 	thermostat
# 	maximising
# Some words which never appear in Statistics papers:
# 	metaheuristic
# 	inpatient
# 	admission
# 	keypoints
# 	enclosing
# 	avoidance
# 	disambiguating
# 	enumerate
# 	illumination
# 	syntactic
# 	transposition
# 	pervasive
# 	shanghaitech
# 	incentive
# 	microscopic
# 	pathologists
# 	erroneously
# 	metastases
# 	entailments
# 	meaningfulness

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.050826774055769e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.74
